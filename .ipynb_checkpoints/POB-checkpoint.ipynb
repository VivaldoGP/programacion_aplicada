# %%
import pandas as pd
import matplotlib.pyplot as plt
from main import countries_data, plot_graph

# %%
data = pd.read_csv("world_pop.csv")

# %%
test_list = ['ZWE', 'ZAF', 'AGO', 'CHN']

# %%
a = countries_data("world_pop.csv", countries_list=test_list)
# Out:
# L for a given list of countries, R for random choice of countries:  R
# ['BHS', 'MDA', 'IRN', 'TSS', 'KNA', 'CUW', 'UGA']

# %%
plot_graph(data=a, year="2020")
